# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- ---------------
# absl-py                            1.4.0
# adal                               1.2.7
# aiohttp                            3.9.3
# aiosignal                          1.3.1
# alabaster                          0.7.12
# altair                             4.1.0
# anaconda-client                    1.11.0
# anaconda-navigator                 2.4.0
# anaconda-project                   0.11.1
# anyascii                           0.3.2
# anyio                              3.5.0
# appdirs                            1.4.4
# argcomplete                        2.0.0
# argh                               0.26.2
# argon2-cffi                        21.3.0
# argon2-cffi-bindings               21.2.0
# arrow                              1.2.2
# asn1crypto                         1.5.1
# astroid                            2.11.7
# astropy                            5.1
# ...
